# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft

duree_signal=100
duree_avec_padding=1000
signal=np.sin(2*np.pi*0.1*np.arange(100))
signal_padde=np.concatenate((signal,np.zeros(duree_avec_padding-duree_signal)))
plt.figure(1)
# crearion de point et norlisation
f=np.arange(duree_avec_padding)/duree_avec_padding
plt.plot(f,np.abs(fft(signal_padde)))
plt.figure(2)
plt.plot(f-1/2,np.abs(np.fft.fftshift(fft(signal_padde))))
plt.xlim([-0.2 , 0.2])
# NB : l’ajout de zeros à un signal, pour augmenter la résolution fréquentielle
# de la TFD, peut être simulé sns explicitement ajouter des 0
plt.figure(3)
plt.plot(f-1/2,abs(np.fft.fftshift(fft(signal,duree_avec_padding))))
plt.xlim([-0.2 , 0.2])
# Out:
# (-0.2, 0.2)

# %% [markdown]
# # Exercice 1

# %%
from scipy.signal import hanning, hamming, blackman
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## superposition les signaux temporels

# %%
K = 100

f = np.linspace(-np.pi, np.pi, 100)
signal_hamming = hamming(K)
signal_haning = hanning(K)
signal_blackman = blackman(K)
plt.figure(1, figsize=(10, 8))
plt.plot(f, signal_hamming, label="signal de Hamming")
plt.plot(f, signal_haning, label="signal de Hanning")
plt.plot(f, signal_blackman, label="signal de Blackman")
plt.plot(f, np.ones(K), label="signal rectangle")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/632010725.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   signal_haning = hanning(K)

# %% [markdown]
# ## Résultat de la multiplication d’un sinus par chacune des fenêtres

# %%
K = 100
f = np.linspace(-np.pi, np.pi, K)*10


plt.figure(1, figsize=(18, 9))
plt.plot(f, np.sin(f)*hamming(K), label="signal de produit  sinus*Hamming")
plt.plot(f, np.sin(f)*hanning(K), label="signal de produit  sinus*Hanning")
plt.plot(f, np.sin(f)*blackman(K), label="signal de de produit  sinus*Blackman")
plt.plot(f, np.sin(f), label="sinus")
plt.plot(f, np.ones(K), label="signal rectangle")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/454125670.py:7: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   plt.plot(f, np.sin(f)*hanning(K), label="signal de produit  sinus*Hanning")

# %%
K = 100*10
f = np.linspace(-np.pi, np.pi, K)*10


plt.figure(1, figsize=(18, 9))
plt.plot(f, np.sin(f)*hamming(K), label="signal de produit  sinus*Hamming")
plt.plot(f, np.sin(f)*hanning(K), label="signal de produit  sinus*Hanning")
plt.plot(f, np.sin(f)*blackman(K), label="signal de de produit  sinus*Blackman")
plt.plot(f, np.sin(f), label="sinus")
plt.plot(f, np.ones(K), label="signal rectangle")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/3990506821.py:7: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   plt.plot(f, np.sin(f)*hanning(K), label="signal de produit  sinus*Hanning")

# %% [markdown]
# ## spectres de chacune des fenêtres à une echelle lineaire

# %%
K = 100

f = np.linspace(-np.pi, np.pi, 1000)
signal_hamming = hamming(K)
signal_haning = hanning(K)
signal_blackman = blackman(K)


plt.figure(figsize=(18, 8))
plt.plot(f,np.abs(np.fft.fftshift(fft(signal_hamming, 1000))), label="spectre de hamming")
plt.plot(f,np.abs(np.fft.fftshift(fft(signal_haning, 1000))),  label="spectre de hanning")
plt.plot(f,np.abs(np.fft.fftshift(fft(signal_blackman, 1000))),  label="spectre de blackman")
plt.xlim([-.5, .5])
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/291319935.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   signal_haning = hanning(K)

# %% [markdown]
# ## spectres de chacune des fenêtres logarithmique

# %%
K = 100

f = np.arange(1000)
signal_hamming = hamming(K)
signal_haning = hanning(K)
signal_blackman = blackman(K)

puissance_hanning = np.sum(signal_haning**2)/signal_haning.size 
puissance_hamming = np.sum(signal_haning**2)/signal_hamming.size 
puissance_blackman = np.sum(signal_haning**2)/signal_blackman.size 


plt.figure(figsize=(18, 8))
plt.plot(f,20*np.log(np.abs(np.fft.fftshift(fft(signal_haning, 1000)))),  label="spectre de hanning")
plt.plot(f,20*np.log(np.abs(np.fft.fftshift(fft(signal_hamming, 1000)))), label="spectre de hamming")
plt.plot(f,20*np.log(np.abs(np.fft.fftshift(fft(signal_blackman, 1000)))),  label="spectre de blackman")


plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/2104833251.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   signal_haning = hanning(K)

# %%
K = 100

f = (np.arange(10000)/10000)-0.5
signal_hamming = hamming(K)
signal_haning = hanning(K)
signal_blackman = blackman(K)
rect = np.ones(K)
puissance_hanning = np.sum(signal_haning**2)
puissance_hamming = np.sum(signal_hamming**2)
puissance_blackman = np.sum(signal_blackman**2)
puissance_rect = np.sum(rect**2)


plt.figure(figsize=(18, 8))
plt.plot(f,20*np.log10(np.abs(np.fft.fftshift(fft(signal_haning, 10000)))),  label=f"spectre de hanning {puissance_hanning}")
plt.plot(f,20*np.log10(np.abs(np.fft.fftshift(fft(signal_hamming, 10000)))), label=f"spectre de hamming {puissance_hamming}")
plt.plot(f,20*np.log10(np.abs(np.fft.fftshift(fft(signal_blackman, 10000)))),  label=f"spectre de blackman {puissance_blackman}")
plt.plot(f,20*np.log10(np.abs(np.fft.fftshift(fft(rect, 10000)))),  label=f"spectre de rectangle {puissance_hanning}")
plt.ylim([-100, 80])
plt.xlim([-.05, .05])
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_10163/2863303056.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   signal_haning = hanning(K)
# /tmp/ipykernel_10163/2863303056.py:18: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f,20*np.log10(np.abs(np.fft.fftshift(fft(rect, 10000)))),  label=f"spectre de rectangle {puissance_hanning}")

# %%
import pandas as pd

df = pd.DataFrame(data=np.zeros((4, 3)))
df.columns = ["Largeur du loge principal", "Attenuation en DB", "Puissance sous la fenetre"]
df.index = ["Rectangle", "HAmming", "Hanning", "BlackMan"]

df["Largeur du loge principal"] = [0.1, 0.04, 0.04, 0.06]
df["Attenuation en DB"] = [13,31,41,57]
df["Puissance sous la fenetre"] = [puissance_rect, puissance_hamming, puissance_hanning, puissance_blackman]
df
# Out:
#            Largeur du loge principal  Attenuation en DB  \
# Rectangle                       0.10                 13
# HAmming                         0.04                 31
# Hanning                         0.04                 41
# BlackMan                        0.06                 57
#
#            Puissance sous la fenetre
# Rectangle                   100.0000
# HAmming                      39.3490
# Hanning                      37.1250
# BlackMan                     30.1554

# %% [markdown]
# # Exercice 2 – Influence des différentes fenêtres sur la résolution fréquentielle de la TFD

# %%
f1=130 
f2=150
amplitude=1
fe=1000
temps=np.arange(fe)/fe
signal=amplitude*np.sin(2*np.pi*f1*temps)+np.sin(2*np.pi*f2*temps)
plt.figure(figsize=(18, 8))
plt.plot(signal)
plt.title('Signal constitué de deux sinusoïdes de 130 Hz et 150 Hz')
plt.xlabel('Temps')
plt.ylabel('Amplitude')
plt.grid(True)

# %% [markdown]
# # Sur 32 points

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=32
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)


fig,axe=plt.subplots(4, 1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title("fenetre de hanning")
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/4204691982.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %% [markdown]
# # Sur 64 points

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=64
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)

fig,axe=plt.subplots(4,1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title('fenêtre hanning')
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/116210584.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %% [markdown]
# # Sur 128 points

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=128
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)

fig,axe=plt.subplots(4,1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title('fenêtre hanning')
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/3921962061.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %% [markdown]
# # Quelle est l’effet de la modification de la durée du signal, expliquez.

# %% [markdown]
# ## Ca dimunie la bande de transition et augmente les oscillation sur la bande attenuer

# %% [markdown]
# # Exercice 3 – Influence des différentes fenêtres sur la résolution en amplitude de la TFD

# %%
f1=130 
f2=300
amplitude=1
fe=1000
temps=np.arange(fe)/fe
signal=amplitude*np.sin(2*np.pi*f1*temps)+ 1/100*np.sin(2*np.pi*f2*temps)
plt.figure(figsize=(18, 8))
plt.plot(signal)
plt.title('Signal constitué de deux sinusoïdes de 130 Hz et 300 Hz')
plt.xlabel('Temps')
plt.ylabel('Amplitude')
plt.grid(True)

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=32
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)

fig,axe=plt.subplots(4,1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title('fenêtre hanning')
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/2996237571.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=64
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)

fig,axe=plt.subplots(4,1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title('fenêtre hanning')
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/116210584.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %%
#Vous créerez des signaux contenant les K = 100 premiers points de chaque fenêtre
k=128
rect=np.ones(k)
rect=np.concatenate((rect,np.zeros(fe-k)))
han=hanning(k)
han=np.concatenate((han,np.zeros(fe-k)))
hamm=hamming(k)
hamm=np.concatenate((hamm,np.zeros(fe-k)))
black=blackman(k)
black=np.concatenate((black,np.zeros(fe-k)))
x=np.arange(512)

fig,axe=plt.subplots(4,1, figsize=(18, 12))
plt.subplots_adjust(hspace=0.9)
axe[0].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(rect*signal,512)))))
axe[0].set_title('fenêtre rectangle')
axe[1].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(han*signal,512)))))
axe[1].set_title('fenêtre hanning')
axe[2].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(hamm*signal,512)))))
axe[2].set_title('fenêtre haming')
axe[3].plot(x,20*np.log10(np.abs(np.fft.fftshift(fft(black*signal,512)))))
axe[3].set_title('fenêtre blackman')
# Out:
# /tmp/ipykernel_10163/3921962061.py:5: DeprecationWarning: `hanning` is deprecated, use `scipy.signal.windows.hann` instead!
#   han=hanning(k)
# Text(0.5, 1.0, 'fenêtre blackman')

# %% [markdown]
# - On se rend compte qu'avec la fenetre du rectangle on a une seul lobe
# - alors qu'avec les fenetre de hamming , hanning et blackman on en a deux
#
# On pour analyser un signal les fenetres de hamming , hanning et blackman soont plus appropier car il emmansine plus de frequences
